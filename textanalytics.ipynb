# %%
# Text cleaning/create tokens

import spacy
spacy.load('en')
from spacy.lang.en import English
parser = English()
def tokenize(text):
    lda_tokens = []
    tokens = parser(text)
    for token in tokens:
        if token.orth_.isspace():
            continue
        elif token.like_url:
            lda_tokens.append('URL')
        elif token.orth_.startswith('@'):
            lda_tokens.append('SCREEN_NAME')
        else:
            lda_tokens.append(token.lower_)
    return lda_tokens

# %%
# find the meanings of words, synonyms. Lemmatizer to get the root word
import nltk
nltk.download('wordnet')
from nltk.corpus import wordnet as wn
def get_lemma(word):
    lemma = wn.morphy(word)
    if lemma is None:
        return word
    else:
        return lemma
    
from nltk.stem.wordnet import WordNetLemmatizer
def get_lemma2(word):
    return WordNetLemmatizer().lemmatize(word)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Mukil\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
#Filter stop words:

nltk.download('stopwords')
en_stop = set(nltk.corpus.stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Mukil\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#Prepare text of topic modelling

def prepare_text_for_lda(text):
    tokens = tokenize(text)
    tokens = [token for token in tokens if len(token) > 2]
    tokens = [token for token in tokens if token not in en_stop]
    tokens = [get_lemma(token) for token in tokens]
    return tokens

# %%
# text data is converted to tokens
import random
text_data = []
with open('C:/Users/Mukil/Documents/Untitled Folder/analytics.csv', encoding="utf8") as f:
    for line in f:
        tokens = prepare_text_for_lda(line)
        if random.random() > .5:
            print(tokens)
            text_data.append(tokens)
# Out:
# ['receive', 'onboarding', 'work', 'mail', 'still', "n't", 'device', 'access', 'think', 'sent', 'personal', 'mail']
# ['manager', 'kind', 'helpful', 'first', 'days', 'make', 'feel', 'comfortable', 'beginning', 'experience', 'company']
# ['would', 'like', 'infor', 'part', 'team']
# ['induction', 'day', 'informative', 'interactive', 'presenter', 'good', 'keeping', 'everyone', 'engage', 'throughout', 'day', 'would', 'recommend', 'new', 'colleague', 'attend', 'day']
# ['receive', 'warm', 'welcome', 'manager', 'also', 'peer', 'everybody', 'helpful', 'kind', 'office', 'make', 'lot', 'easy', 'settle', 'question', 'problem', 'quickly', 'answer', 'resolve']
# ['employee', 'onboarding', 'must', 'improve', 'computer', 'email', 'computer', 'bag', 'mouse', 'mobile', 'phone', 'sim', 'readiness', 'place', 'need', 'day1']
# ['nice', 'friendly']
# ['supervisor', 'treat', 'kindly', 'always', 'put', 'first', 'place', 'personal', 'career', 'goal', 'gain', 'work']
# ...

# %%
#LDA with gensim - create dictionary from the data
from gensim import corpora
dictionary = corpora.Dictionary(text_data)
corpus = [dictionary.doc2bow(text) for text in text_data]
import pickle
pickle.dump(corpus, open('corpus.pkl', 'wb'))
dictionary.save('dictionary.gensim')

# %%
# LDA to find 10 topics
import gensim
NUM_TOPICS = 10
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=15)
ldamodel.save('model5.gensim')
topics = ldamodel.print_topics(num_words=6)
for topic in topics:
    print(topic)
# Out:
# (0, '0.022*"interview" + 0.021*"experience" + 0.011*"time" + 0.010*"job" + 0.010*"company" + 0.010*"would"')
# (1, '0.079*"easy" + 0.031*"site" + 0.025*"apply" + 0.021*"use" + 0.012*"navigate" + 0.012*"job"')
# (2, '0.026*"application" + 0.022*"great" + 0.016*"company" + 0.016*"experience" + 0.014*"process" + 0.014*"nice"')
# (3, '0.019*"information" + 0.015*"question" + 0.013*"onboarding" + 0.010*"receive" + 0.010*"would" + 0.009*"get"')
# (4, '0.027*"interview" + 0.016*"process" + 0.013*"really" + 0.012*"schlumberger" + 0.011*"engage" + 0.011*"organize"')
# (5, '0.015*"interview" + 0.012*"people" + 0.012*"professional" + 0.011*"experience" + 0.011*"day" + 0.011*"one"')
# (6, '0.024*"would" + 0.017*"get" + 0.015*"nice" + 0.015*"need" + 0.012*"none" + 0.010*"like"')
# (7, '0.023*"process" + 0.020*"get" + 0.017*"interview" + 0.013*"role" + 0.012*"easy" + 0.012*"experience"')
# ...

# %%
#Saliency: a measure of how much the term tells you about the topic.
#Relevance: a weighted average of the probability of the word given the topic and the word given the topic normalized by the probability of the topic.
#The size of the bubble measures the importance of the topics, relative to the data.
#First, we got the most salient terms, means terms mostly tell us about what’s going on relative to the topics. We can also look at individual topic.

# %%
# pyLDAvis to visualize the topic

dictionary = gensim.corpora.Dictionary.load('dictionary.gensim')
corpus = pickle.load(open('corpus.pkl', 'rb'))
lda = gensim.models.ldamodel.LdaModel.load('model5.gensim')
import pyLDAvis.gensim
lda_display = pyLDAvis.gensim.prepare(lda, corpus, dictionary, sort_topics=False)
pyLDAvis.display(lda_display)
# Out:
# C:\Users\Mukil\Anaconda3\lib\site-packages\pyLDAvis\_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el4216431766043643763887799911"></div>
# <script type="text/javascript">
#
# ...
